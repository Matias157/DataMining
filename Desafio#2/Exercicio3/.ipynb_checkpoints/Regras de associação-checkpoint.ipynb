# %% [markdown]
# # Apriori - Mineração de regras frequentes

# %%
#Usando a implementação do Apriori disponível na biblioteca mlxtend
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# ### Exemplo ilustrado nos slides

# %%
#Formato de lista de listas (cada lista simula uma transação)
tranactions_exmplo  =   [['Pao','Leite', 'Manteiga'],
                         ['Pao','Leite','Acucar'],
                         ['Pao'],
                         ['Pao','Leite'],
                         ['Pao','Leite','Manteiga','Acucar']]

#Recurso da biblioteca mlxtend para codificar transações no padrão one-hot dataframe.
te = TransactionEncoder()
encoded = te.fit(tranactions_exmplo).transform(tranactions_exmplo)

dfExemplo = pd.DataFrame(encoded, columns=te.columns_)
dfExemplo
# Out:
#    Acucar  Leite  Manteiga   Pao
# 0   False   True      True  True
# 1    True   True     False  True
# 2   False  False     False  True
# 3   False   True     False  True
# 4    True   True      True  True

# %%
frequent_itemsets = apriori(dfExemplo, min_support=0.4, use_colnames=True)
frequent_itemsets
# Out:
#     support                itemsets
# 0       0.4                (Acucar)
# 1       0.8                 (Leite)
# 2       0.4              (Manteiga)
# 3       1.0                   (Pao)
# 4       0.4         (Acucar, Leite)
# 5       0.4           (Acucar, Pao)
# 6       0.4       (Manteiga, Leite)
# 7       0.8            (Pao, Leite)
# 8       0.4         (Pao, Manteiga)
# 9       0.4    (Acucar, Pao, Leite)
# 10      0.4  (Pao, Manteiga, Leite)

# %% [markdown]
# ## Exemplo com o dataset do filme Titanic

# %% [markdown]
# ### Dataset e Preprocessamento

# %%
dfTitanicFull = pd.read_csv('titanic.csv')


#Excluindo as features que não quero itentificar associações
dfTitanic = dfTitanicFull.drop(columns=['Name','Parents/Children Aboard','Siblings/Spouses Aboard','Fare'])

# Trocando os valores binários para um string
mudar_status = {0: "Morreu", 1: "Sobreviveu"}
dfTitanic.replace({'Survived' : mudar_status}, inplace=True)

mudar_classe = {1: "1-classe", 2: "2-classe", 3:"3-classe"}
dfTitanic.replace({'Pclass' : mudar_classe}, inplace=True)

#Criando labels para as idades
dfTitanic['Age'] = pd.cut(dfTitanic.Age,bins=[0,17,65,120],labels=['Crianca','Adulto','Idoso'])

dfTitanic
# Out:
#        Survived    Pclass     Sex      Age
# 0        Morreu  3-classe    male   Adulto
# 1    Sobreviveu  1-classe  female   Adulto
# 2    Sobreviveu  3-classe  female   Adulto
# 3    Sobreviveu  1-classe  female   Adulto
# 4        Morreu  3-classe    male   Adulto
# ..          ...       ...     ...      ...
# 882      Morreu  2-classe    male   Adulto
# 883  Sobreviveu  1-classe  female   Adulto
# 884      Morreu  3-classe  female  Crianca
# 885  Sobreviveu  1-classe    male   Adulto
# 886      Morreu  3-classe    male   Adulto
#
# [887 rows x 4 columns]

# %% [markdown]
# ### Transformações necessárias

# %%
transactions = []
numLines = dfTitanic.shape[0]
numColumns = dfTitanic.shape[1]

#Transforma para lista de listas (ideia de transações)
for i in range(0,numLines):
    transactions.append([str(dfTitanic.values[i,j]) for j in range(0,numColumns)])

#Recurso da biblioteca mlxtend para codificar transações no padrão one-hot dataframe.
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)

df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#      1-classe  2-classe  3-classe  Adulto  Crianca  Idoso  Morreu  Sobreviveu  \
# 0       False     False      True    True    False  False    True       False
# 1        True     False     False    True    False  False   False        True
# 2       False     False      True    True    False  False   False        True
# 3        True     False     False    True    False  False   False        True
# 4       False     False      True    True    False  False    True       False
# ..        ...       ...       ...     ...      ...    ...     ...         ...
# 882     False      True     False    True    False  False    True       False
# 883      True     False     False    True    False  False   False        True
# 884     False     False      True   False     True  False    True       False
# 885      True     False     False    True    False  False   False        True
# 886     False     False      True    True    False  False    True       False
#
#      female   male
# 0     False   True
# 1      True  False
# 2      True  False
# 3      True  False
# 4     False   True
# ..      ...    ...
# 882   False   True
# 883    True  False
# 884    True  False
# 885   False   True
# 886   False   True
#
# [887 rows x 10 columns]

# %% [markdown]
# ### Itemsets frequentes

# %%
#Itemsets frquequentes com esse suporte informado
frequent_itemsets = apriori(df, min_support=0.1, use_colnames=True)
print(frequent_itemsets.to_string())
# Out:
#      support                          itemsets
# 0   0.243517                        (1-classe)
# 1   0.207441                        (2-classe)
# 2   0.549042                        (3-classe)
# 3   0.842165                          (Adulto)
# 4   0.146561                         (Crianca)
# 5   0.614431                          (Morreu)
# 6   0.385569                      (Sobreviveu)
# 7   0.354002                          (female)
# 8   0.645998                            (male)
# 9   0.225479                (Adulto, 1-classe)
# 10  0.153326            (Sobreviveu, 1-classe)
# 11  0.105975                (1-classe, female)
# 12  0.137542                  (male, 1-classe)
# 13  0.179256                (Adulto, 2-classe)
# 14  0.109357                (2-classe, Morreu)
# 15  0.121759                  (male, 2-classe)
# 16  0.437430                (Adulto, 3-classe)
# 17  0.107103               (Crianca, 3-classe)
# 18  0.414882                (Morreu, 3-classe)
# 19  0.134160            (Sobreviveu, 3-classe)
# 20  0.162345                (3-classe, female)
# 21  0.386697                  (male, 3-classe)
# 22  0.531003                  (Adulto, Morreu)
# 23  0.311161              (Sobreviveu, Adulto)
# 24  0.282976                  (Adulto, female)
# 25  0.559188                    (male, Adulto)
# 26  0.523112                    (male, Morreu)
# 27  0.262683              (Sobreviveu, female)
# 28  0.122886                (Sobreviveu, male)
# 29  0.139797    (Sobreviveu, Adulto, 1-classe)
# 30  0.128523          (male, Adulto, 1-classe)
# 31  0.102593    (Sobreviveu, 1-classe, female)
# 32  0.104848        (Adulto, 2-classe, Morreu)
# 33  0.107103          (male, Adulto, 2-classe)
# 34  0.102593          (male, 2-classe, Morreu)
# 35  0.340474        (Adulto, Morreu, 3-classe)
# 36  0.113867        (3-classe, Adulto, female)
# 37  0.323563          (male, Adulto, 3-classe)
# 38  0.333709          (male, Morreu, 3-classe)
# 39  0.465614            (male, Adulto, Morreu)
# 40  0.217587      (Sobreviveu, Adulto, female)
# 41  0.284104  (male, Adulto, Morreu, 3-classe)

# %% [markdown]
# ### Regras de associação

# %%
#Regras com o valor de confiança mínimo escolhido
dfRegras= association_rules(frequent_itemsets, metric='confidence', min_threshold=0.5)
dfRegras
# Out:
#            antecedents             consequents  antecedent support  \
# 0           (1-classe)                (Adulto)            0.243517
# 1           (1-classe)            (Sobreviveu)            0.243517
# 2           (1-classe)                  (male)            0.243517
# 3           (2-classe)                (Adulto)            0.207441
# 4           (2-classe)                (Morreu)            0.207441
# ..                 ...                     ...                 ...
# 73    (male, 3-classe)        (Adulto, Morreu)            0.386697
# 74    (Adulto, Morreu)        (male, 3-classe)            0.531003
# 75  (Adulto, 3-classe)          (male, Morreu)            0.437430
# 76  (Morreu, 3-classe)          (male, Adulto)            0.414882
# 77          (3-classe)  (male, Adulto, Morreu)            0.549042
#
#     consequent support   support  confidence      lift  leverage  conviction
# 0             0.842165  0.225479    0.925926  1.099460  0.020397    2.130778
# 1             0.385569  0.153326    0.629630  1.632987  0.059433    1.658963
# 2             0.645998  0.137542    0.564815  0.874329 -0.019769    0.813452
# 3             0.842165  0.179256    0.864130  1.026083  0.004557    1.161669
# 4             0.614431  0.109357    0.527174  0.857988 -0.018101    0.815457
# ..                 ...       ...         ...       ...       ...         ...
# 73            0.531003  0.284104    0.734694  1.383595  0.078766    1.767756
# 74            0.386697  0.284104    0.535032  1.383595  0.078766    1.319022
# 75            0.523112  0.284104    0.649485  1.241579  0.055279    1.360535
# 76            0.559188  0.284104    0.684783  1.224601  0.052107    1.398437
# 77            0.465614  0.284104    0.517454  1.111335  0.028462    1.107429
#
# [78 rows x 9 columns]

# %%
#Scatter plot da confiança e suporte. Auxilia no entendimento do espaço de regras
plt.scatter(data = dfRegras, x='support', y='confidence', edgecolors='red')
plt.xlabel('supporte')
plt.ylabel('confiança')
plt.show()

# %%
#Filtrando regras apenas com o consequente "Sobreviveu" ou "Morreu"
dfRegras[(dfRegras['consequents'] == {'Sobreviveu'}) | (dfRegras['consequents'] == {'Morreu'}) ]
# Out:
#                  antecedents   consequents  antecedent support  \
# 1                 (1-classe)  (Sobreviveu)            0.243517
# 4                 (2-classe)      (Morreu)            0.207441
# 10                (3-classe)      (Morreu)            0.549042
# 13                  (Adulto)      (Morreu)            0.842165
# 19                    (male)      (Morreu)            0.645998
# 22                  (female)  (Sobreviveu)            0.354002
# 24        (Adulto, 1-classe)  (Sobreviveu)            0.225479
# 30        (1-classe, female)  (Sobreviveu)            0.105975
# 31        (Adulto, 2-classe)      (Morreu)            0.179256
# 37          (male, 2-classe)      (Morreu)            0.121759
# 40        (Adulto, 3-classe)      (Morreu)            0.437430
# 51          (male, 3-classe)      (Morreu)            0.386697
# 56            (male, Adulto)      (Morreu)            0.559188
# 64          (Adulto, female)  (Sobreviveu)            0.282976
# 68  (male, Adulto, 3-classe)      (Morreu)            0.323563
#
#     consequent support   support  confidence      lift  leverage  conviction
# 1             0.385569  0.153326    0.629630  1.632987  0.059433    1.658963
# 4             0.614431  0.109357    0.527174  0.857988 -0.018101    0.815457
# 10            0.614431  0.414882    0.755647  1.229833  0.077534    1.577918
# 13            0.614431  0.531003    0.630522  1.026189  0.013552    1.043552
# 19            0.614431  0.523112    0.809773  1.317924  0.126191    2.026892
# 22            0.385569  0.262683    0.742038  1.924526  0.126191    2.381867
# 24            0.385569  0.139797    0.620000  1.608012  0.052859    1.616923
# 30            0.385569  0.102593    0.968085  2.510794  0.061732   19.252161
# 31            0.614431  0.104848    0.584906  0.951947 -0.005293    0.928872
# 37            0.614431  0.102593    0.842593  1.371339  0.027781    2.449499
# 40            0.614431  0.340474    0.778351  1.266783  0.071703    1.739545
# 51            0.614431  0.333709    0.862974  1.404510  0.096111    2.813836
# 56            0.614431  0.465614    0.832661  1.355175  0.122032    2.304125
# 64            0.385569  0.217587    0.768924  1.994257  0.108480    2.659002
# 68            0.614431  0.284104    0.878049  1.429045  0.085297    3.161669

# %%
#Conta quantos elementos tem no antecedente e armazena esse valor em "antecedent_len"
dfRegras["antecedent_len"] = dfRegras["antecedents"].apply(lambda x: len(x))

#Filtra regras com pelo menos dois elementos no antecedente, com lift>1 e consequente "Sobreviveu" ou "Morreu"
dfRegras[ (dfRegras['antecedent_len'] >= 2) &
          (dfRegras['lift'] > 1) &
          ((dfRegras['consequents'] == {'Sobreviveu'}) | (dfRegras['consequents'] == {'Morreu'}))]
# Out:
#                  antecedents   consequents  antecedent support  \
# 24        (Adulto, 1-classe)  (Sobreviveu)            0.225479
# 30        (1-classe, female)  (Sobreviveu)            0.105975
# 37          (male, 2-classe)      (Morreu)            0.121759
# 40        (Adulto, 3-classe)      (Morreu)            0.437430
# 51          (male, 3-classe)      (Morreu)            0.386697
# 56            (male, Adulto)      (Morreu)            0.559188
# 64          (Adulto, female)  (Sobreviveu)            0.282976
# 68  (male, Adulto, 3-classe)      (Morreu)            0.323563
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 24            0.385569  0.139797    0.620000  1.608012  0.052859    1.616923
# 30            0.385569  0.102593    0.968085  2.510794  0.061732   19.252161
# 37            0.614431  0.102593    0.842593  1.371339  0.027781    2.449499
# 40            0.614431  0.340474    0.778351  1.266783  0.071703    1.739545
# 51            0.614431  0.333709    0.862974  1.404510  0.096111    2.813836
# 56            0.614431  0.465614    0.832661  1.355175  0.122032    2.304125
# 64            0.385569  0.217587    0.768924  1.994257  0.108480    2.659002
# 68            0.614431  0.284104    0.878049  1.429045  0.085297    3.161669
#
#     antecedent_len
# 24               2
# 30               2
# 37               2
# 40               2
# 51               2
# 56               2
# 64               2
# 68               3

# %% [markdown]
# ### Mesmo exemplo usando fp-Growth

# %%
from mlxtend.frequent_patterns import fpgrowth

frequentFpGrowth= fpgrowth(df, min_support=0.1, use_colnames=True)

dfRegrasFP= association_rules(frequentFpGrowth, metric='confidence', min_threshold=0.5)

dfRegrasFP["antecedent_len"] = dfRegrasFP["antecedents"].apply(lambda x: len(x))
dfRegrasFP[ (dfRegrasFP['antecedent_len'] >= 2) &
            (dfRegrasFP['lift'] > 1) &
           ((dfRegrasFP['consequents'] == {'Sobreviveu'}) | (dfRegrasFP['consequents'] == {'Morreu'}))]
# Out:
#                  antecedents   consequents  antecedent support  \
# 6             (male, Adulto)      (Morreu)            0.559188
# 19        (Adulto, 3-classe)      (Morreu)            0.437430
# 24          (male, 3-classe)      (Morreu)            0.386697
# 35  (male, Adulto, 3-classe)      (Morreu)            0.323563
# 51          (Adulto, female)  (Sobreviveu)            0.282976
# 59        (Adulto, 1-classe)  (Sobreviveu)            0.225479
# 62        (1-classe, female)  (Sobreviveu)            0.105975
# 76          (male, 2-classe)      (Morreu)            0.121759
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 6             0.614431  0.465614    0.832661  1.355175  0.122032    2.304125
# 19            0.614431  0.340474    0.778351  1.266783  0.071703    1.739545
# 24            0.614431  0.333709    0.862974  1.404510  0.096111    2.813836
# 35            0.614431  0.284104    0.878049  1.429045  0.085297    3.161669
# 51            0.385569  0.217587    0.768924  1.994257  0.108480    2.659002
# 59            0.385569  0.139797    0.620000  1.608012  0.052859    1.616923
# 62            0.385569  0.102593    0.968085  2.510794  0.061732   19.252161
# 76            0.614431  0.102593    0.842593  1.371339  0.027781    2.449499
#
#     antecedent_len
# 6                2
# 19               2
# 24               2
# 35               3
# 51               2
# 59               2
# 62               2
# 76               2
